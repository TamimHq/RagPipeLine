# %%
# @title Install dependencies (run once, then Runtime -> Restart session)
# !pip -q install google-genai pymupdf sentence-transformers langchain-text-splitters \
                chromadb rank_bm25 pysqlite3-binary

print("Done. Now: Runtime -> Restart session, then continue from cell 2.")
# Out:
# Done. Now: Runtime -> Restart session, then continue from cell 2.

# %%
# @title Load API key and create the Gemini client
import os
from google import genai
from google.genai import types

try:
    from google.colab import userdata
    os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")
except ImportError:
    pass

assert os.environ.get("GEMINI_API_KEY"), "GEMINI_API_KEY not set — add it in the Secrets panel."
client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

# Aliases, so a model retirement doesn't 404 the whole notebook.
CHAT_MODEL = "gemini-3.5-flash-lite"
OCR_MODEL  = "gemini-3.5-flash-lite"

print("Models available to this key:")
for m in client.models.list():
    if "generateContent" in getattr(m, "supported_actions", []) or True:
        print("  ", m.name)
# Out:
# Models available to this key:
#    models/gemini-2.5-flash
#    models/gemini-2.5-pro
#    models/gemini-2.0-flash
#    models/gemini-2.0-flash-001
#    models/gemini-2.0-flash-lite-001
#    models/gemini-2.0-flash-lite
#    models/gemini-2.5-flash-preview-tts
#    models/gemini-2.5-pro-preview-tts
#    models/gemma-4-26b-a4b-it
#    models/gemma-4-31b-it
#    models/gemini-flash-latest
#    models/gemini-flash-lite-latest
#    models/gemini-pro-latest
#    models/gemini-2.5-flash-lite
#    models/gemini-2.5-flash-image
#    models/gemini-3-pro-preview
#    models/gemini-3-flash-preview
#    models/gemini-3.1-pro-preview
#    models/gemini-3.1-pro-preview-customtools
#    models/gemini-3.1-flash-lite-preview
#    models/gemini-3.1-flash-lite
#    models/gemini-3-pro-image-preview
#    models/gemini-3-pro-image
#    models/nano-banana-pro-preview
#    models/gemini-3.1-flash-image-preview
#    models/gemini-3.1-flash-image
#    models/gemini-3.1-flash-lite-image
# ...

# %%
# @title Imports + config

# Colab's bundled sqlite3 is sometimes older than chromadb's minimum (3.35)
import sqlite3
if sqlite3.sqlite_version_info < (3, 35, 0):
    import sys
    __import__("pysqlite3")
    sys.modules["sqlite3"] = sys.modules.pop("pysqlite3")

import re
import time
import unicodedata
from typing import List, Dict, Tuple

import fitz                      # PyMuPDF — renders pages, no poppler needed
import numpy as np
import chromadb
from sentence_transformers import SentenceTransformer
from langchain_text_splitters import RecursiveCharacterTextSplitter
from rank_bm25 import BM25Okapi

# --- storage ---
CHROMA_DB_PATH  = "/content/chroma_db"     # point at /content/drive/MyDrive/... to persist
COLLECTION_NAME = "bangla_rag"
OCR_CACHE       = "/content/ocr_cache"     # a crash won't cost you the whole OCR run
EMBEDDING_MODEL = "sentence-transformers/LaBSE"

# --- OCR ---
OCR_DPI = 200                              # Gemini doesn't need 300; smaller = faster upload

# --- chunking ---
CHUNK_SIZE    = 700                        # ~2-4 Bengali sentences
CHUNK_OVERLAP = 120

# --- retrieval ---
TOP_K            = 8                       # chunks sent to the LLM
PROSE_MIN        = 4                       # slots reserved for answer-bearing prose
CANDIDATES       = 25                      # per-retriever pool before fusion
RRF_K            = 60
DEDUPE_THRESHOLD = 0.8                     # token overlap above this = near-duplicate

print("Config ready.")
# Out:
# Config ready.

# %%
# @title Gemini vision OCR (cached)

OCR_PROMPT = """Transcribe ALL text in this page image exactly as printed.

Rules:
- Bengali script must be character-accurate. Pay close attention to conjuncts
  (ম্ভ, ন্ত, ষ্ট, ক্ষ, স্ত, ঙ্গ) — do not substitute similar-looking ones.
- Preserve the reading order and line breaks of the original.
- For tables, output one row per line with cells separated by " | ".
- Do NOT translate, summarize, correct, or explain anything.
- Output the transcription only, with no preamble and no markdown fences."""


def ocr_pdf(pdf_path: str, force: bool = False) -> List[Tuple[int, str]]:
    """Render each page and transcribe it with Gemini. Cached to OCR_CACHE."""
    os.makedirs(OCR_CACHE, exist_ok=True)
    doc = fitz.open(pdf_path)
    mat = fitz.Matrix(OCR_DPI / 72.0, OCR_DPI / 72.0)
    pages = []

    for i, page in enumerate(doc, start=1):
        cache = f"{OCR_CACHE}/page_{i:03d}.txt"
        if os.path.exists(cache) and not force:
            text = open(cache, encoding="utf-8").read()
            print(f"  page {i:>2}/{len(doc)}: {len(text):>5} chars (cached)")
            pages.append((i, text))
            continue

        png = page.get_pixmap(matrix=mat).tobytes("png")
        text = ""
        for attempt in range(3):
            try:
                r = client.models.generate_content(
                    model=OCR_MODEL,
                    contents=[types.Part.from_bytes(data=png, mime_type="image/png"),
                              OCR_PROMPT],
                    config=types.GenerateContentConfig(temperature=0.0),
                )
                text = (r.text or "").strip()
                break
            except Exception as e:
                print(f"    page {i} attempt {attempt + 1} failed: {e}")
                time.sleep(3 * (attempt + 1))

        with open(cache, "w", encoding="utf-8") as f:
            f.write(text)
        print(f"  page {i:>2}/{len(doc)}: {len(text):>5} chars")
        pages.append((i, text))
        time.sleep(0.5)                      # stay under the free-tier rate limit

    doc.close()
    return pages

print("OCR function defined.")
# Out:
# OCR function defined.

# %%
# @title clean_page / section_of / chunk_pages

BOILERPLATE = [
    r"10\s*MINUTE\s*SCHOOL",
    r"MINUTE\s*SCHOOL",
    r"HSC\s*[২৬\d]*\s*অনলাইন\s*ব্যাচ",
    r"বাংলা\s*[-•·]\s*ইংরেজি\s*[-•·]\s*আইসিটি",
    r"কল\s*করো\s*১৬৯১০",
]


def clean_page(text: str) -> str:
    """Conservative: keeps punctuation, newlines, option labels and উত্তর: lines."""
    text = unicodedata.normalize("NFC", text)
    out = []
    for line in text.split("\n"):
        line = re.sub(r"[ \t\u00a0]+", " ", line).strip()
        if not line:
            out.append("")
            continue
        for pat in BOILERPLATE:
            line = re.sub(pat, " ", line, flags=re.IGNORECASE)
        line = line.strip()
        if not line:
            continue
        if re.fullmatch(r"[\d\u09e6-\u09ef]{1,3}", line):        # bare page number
            continue
        if not re.search(r"[\u0980-\u09FF]|[A-Za-z]", line):     # OCR garbage
            continue
        out.append(line)
    return re.sub(r"\n{3,}", "\n\n", "\n".join(out)).strip()


def section_of(page: int) -> str:
    """Page ranges for this specific PDF — verify with the inspection cell below."""
    if page <= 5:   return "glossary"     # শব্দার্থ ও টীকা
    if page <= 19:  return "prose"        # মূল গল্প + লেখক/পাঠ পরিচিতি  <- answers live here
    if page <= 41:  return "mcq"          # question banks; answer keys sit in a separate grid
    return "solution"                     # সৃজনশীল, with worked answers


def chunk_pages(pages: List[Tuple[int, str]]) -> List[Dict]:
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=CHUNK_SIZE,
        chunk_overlap=CHUNK_OVERLAP,
        separators=["\n\n", "\n", "। ", "।", "? ", "! ", ". ", " ", ""],
        length_function=len,
        keep_separator=True,
    )
    chunks = []
    for page_no, raw in pages:
        cleaned = clean_page(raw)
        if len(cleaned) < 40:
            continue
        sec = section_of(page_no)
        for j, piece in enumerate(splitter.split_text(cleaned)):
            piece = piece.strip()
            if len(piece) < 40:           # only true fragments dropped, no question filter
                continue
            chunks.append({"id": f"p{page_no:03d}_c{j:03d}", "text": piece,
                           "page": page_no, "section": sec})
    return chunks

print("Cleaning and chunking defined.")
# Out:
# Cleaning and chunking defined.

# %%
# @title HybridStore

_TOKEN_RE = re.compile(r"[\u0980-\u09FF]+|[a-z0-9]+")

def tokenize(text: str) -> List[str]:
    """Bengali + latin. NLTK punkt is English-only and near-useless here."""
    return _TOKEN_RE.findall(unicodedata.normalize("NFC", text).lower())


def overlap(a: str, b: str) -> float:
    ta, tb = set(tokenize(a)), set(tokenize(b))
    if not ta or not tb:
        return 0.0
    return len(ta & tb) / min(len(ta), len(tb))


class HybridStore:
    def __init__(self, db_path=CHROMA_DB_PATH, name=COLLECTION_NAME):
        print(f"Loading {EMBEDDING_MODEL} ...")
        self.model = SentenceTransformer(EMBEDDING_MODEL)
        self.client = chromadb.PersistentClient(path=db_path)
        self.collection = self.client.get_or_create_collection(
            name=name, metadata={"hnsw:space": "cosine"})
        self.corpus: List[Dict] = []
        self.bm25 = None
        self._load_corpus()

    # ---------- indexing ----------
    def _embed(self, texts):
        vecs = self.model.encode(texts, batch_size=32, show_progress_bar=True,
                                 normalize_embeddings=True)     # required for cosine
        return np.asarray(vecs).tolist()

    def _load_corpus(self):
        """Rebuild BM25 from Chroma, so hybrid search survives a restart."""
        got = self.collection.get(include=["documents", "metadatas"])
        if not got["ids"]:
            print("Collection is empty.")
            self.corpus, self.bm25 = [], None
            return
        self.corpus = [
            {"id": i, "text": d,
             "page": (m or {}).get("page"),
             "section": (m or {}).get("section", "prose")}
            for i, d, m in zip(got["ids"], got["documents"], got["metadatas"])
        ]
        self.bm25 = BM25Okapi([tokenize(c["text"]) for c in self.corpus])
        by_sec = {}
        for c in self.corpus:
            by_sec[c["section"]] = by_sec.get(c["section"], 0) + 1
        print(f"Loaded {len(self.corpus)} chunks {by_sec}; BM25 index built.")

    def clear(self):
        try:
            self.client.delete_collection(self.collection.name)
        except Exception:
            pass
        self.collection = self.client.get_or_create_collection(
            name=COLLECTION_NAME, metadata={"hnsw:space": "cosine"})
        self.corpus, self.bm25 = [], None
        print("Collection cleared.")

    def add(self, chunks: List[Dict], source: str):
        print(f"Embedding {len(chunks)} chunks ...")
        embs = self._embed([c["text"] for c in chunks])
        B = 256
        for i in range(0, len(chunks), B):
            sl = slice(i, i + B)
            self.collection.add(
                ids=[c["id"] for c in chunks[sl]],
                embeddings=embs[sl],
                documents=[c["text"] for c in chunks[sl]],
                metadatas=[{"source": source, "page": c["page"], "section": c["section"]}
                           for c in chunks[sl]],
            )
        self._load_corpus()

    # ---------- retrieval ----------
    def retrieve(self, query: str, top_k=TOP_K, debug=False) -> List[Dict]:
        if not self.corpus:
            return []

        ranks: Dict[str, float] = {}

        qv = self.model.encode([query], normalize_embeddings=True)[0].tolist()
        vres = self.collection.query(query_embeddings=[qv],
                                     n_results=min(CANDIDATES, len(self.corpus)))
        for rank, cid in enumerate(vres["ids"][0]):
            ranks[cid] = ranks.get(cid, 0.0) + 1.0 / (RRF_K + rank + 1)

        if self.bm25 is not None:
            scores = self.bm25.get_scores(tokenize(query))
            for rank, idx in enumerate(np.argsort(scores)[::-1][:CANDIDATES]):
                if scores[idx] <= 0:
                    continue
                ranks[self.corpus[idx]["id"]] = (
                    ranks.get(self.corpus[idx]["id"], 0.0) + 1.0 / (RRF_K + rank + 1))

        by_id = {c["id"]: c for c in self.corpus}
        ordered = [{**by_id[cid], "score": s}
                   for cid, s in sorted(ranks.items(), key=lambda kv: kv[1], reverse=True)
                   if cid in by_id]

        selected: List[Dict] = []

        def try_add(c) -> bool:
            if len(selected) >= top_k:
                return False
            if any(overlap(c["text"], s["text"]) > DEDUPE_THRESHOLD for s in selected):
                return False
            selected.append(c)
            return True

        for c in ordered:                                  # pass 1: reserved prose slots
            if len(selected) >= PROSE_MIN:
                break
            if c["section"] in ("prose", "solution", "glossary"):
                try_add(c)

        chosen = {s["id"] for s in selected}
        for c in ordered:                                  # pass 2: best of the rest
            if c["id"] not in chosen:
                try_add(c)

        if debug:
            print(f"\n[retrieve] {query!r}")
            for r in selected:
                print(f"  {r['id']} p{r['page']:>2} [{r['section']:<8}] "
                      f"{r['score']:.4f} | {r['text'][:100]}...")
        return selected

print("HybridStore defined.")
# Out:
# HybridStore defined.

# %%
# @title RAG

PROMPT = """তুমি একজন সহায়ক সহকারী। নিচের প্রসঙ্গ (context) ব্যবহার করে প্রশ্নের উত্তর দাও।

নিয়ম:
- উত্তর শুধুমাত্র প্রসঙ্গ থেকে দেবে। প্রসঙ্গে না থাকলে বলবে: "প্রদত্ত তথ্যে উত্তর পাওয়া যায়নি।"
- প্রসঙ্গে বহুনির্বাচনী প্রশ্নের অপশন থাকলে সেগুলোকে উত্তর ধরে নেবে না; মূল গল্প বা ব্যাখ্যা থেকে উত্তর নেবে।
- তথ্য ছড়িয়ে থাকলে জোড়া লাগিয়ে উত্তর দাও।
- ব্যবহারকারী যে ভাষায় প্রশ্ন করেছে সেই ভাষাতেই উত্তর দাও।
- সংক্ষিপ্ত প্রশ্নের উত্তর সংক্ষেপে দাও (এক-দুই শব্দের প্রশ্ন হলে এক-দুই শব্দেই)।

Context:
{context}

Question: {query}

Answer:"""


class RAG:
    def __init__(self, store: HybridStore, model_name: str = CHAT_MODEL):
        self.store = store
        self.model = model_name
        self.history: List[Dict] = []

    def ask(self, query: str, debug: bool = False) -> str:
        chunks = self.store.retrieve(query, debug=debug)
        if not chunks:
            return "প্রদত্ত তথ্যে উত্তর পাওয়া যায়নি। (কোনো চাঙ্ক পাওয়া যায়নি)"
        context = "\n\n---\n\n".join(
            f"[page {c['page']} / {c['section']}]\n{c['text']}" for c in chunks)
        try:
            r = client.models.generate_content(
                model=self.model,
                contents=PROMPT.format(context=context, query=query),
                config=types.GenerateContentConfig(temperature=0.1),
            )
            answer = (r.text or "").strip()
        except Exception as e:
            return f"LLM error: {e}"
        self.history.append({"q": query, "a": answer})
        return answer

print("RAG defined.")
# Out:
# RAG defined.

# %%
# @title Upload PDF
from google.colab import files

uploaded = files.upload()
name = list(uploaded.keys())[0]
PDF_PATH = "/content/" + name
with open(PDF_PATH, "wb") as f:
    f.write(uploaded[name])
print("Saved to", PDF_PATH)
# Out:
#      <input type="file" id="files-0b325372-7ae5-45b5-8d0f-9cd774ed8597" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b325372-7ae5-45b5-8d0f-9cd774ed8597">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# @title Reset (run this if you are re-indexing after changing OCR or chunking)
RESET_OCR_CACHE = True   # set False to keep the cached transcriptions

import shutil
if RESET_OCR_CACHE and os.path.exists(OCR_CACHE):
    shutil.rmtree(OCR_CACHE)
    print("OCR cache cleared.")
if os.path.exists(CHROMA_DB_PATH):
    shutil.rmtree(CHROMA_DB_PATH)
    print("Chroma store cleared.")
# Out:
# OCR cache cleared.

# %%
# @title OCR -> chunk -> index
store = HybridStore()
store.clear()

pages  = ocr_pdf(PDF_PATH)
chunks = chunk_pages(pages)

avg = sum(len(c["text"]) for c in chunks) // max(1, len(chunks))
counts = {}
for c in chunks:
    counts[c["section"]] = counts.get(c["section"], 0) + 1
print(f"\n{len(chunks)} chunks from {len(pages)} pages, avg {avg} chars, sections {counts}")

store.add(chunks, source=os.path.basename(PDF_PATH))
rag = RAG(store)
# Out:
# Loading sentence-transformers/LaBSE ...
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# Collection is empty.
# Collection cleared.
#   page  1/49:   152 chars
#   page  2/49:  1515 chars
#   page  3/49:  1809 chars
#   page  4/49:  1361 chars
#   page  5/49:   459 chars
#   page  6/49:  2265 chars
#   page  7/49:  2224 chars
#   page  8/49:  2545 chars
#   page  9/49:  2160 chars
#   page 10/49:  1777 chars
#   page 11/49:  2118 chars
#   page 12/49:  2468 chars
#   page 13/49:  2257 chars
#   page 14/49:  2319 chars
#   page 15/49:  2472 chars
#   page 16/49:  1818 chars
#   page 17/49:  1278 chars
#   page 18/49:  2076 chars
#   page 19/49:  1902 chars
#   page 20/49:     0 chars
#   page 21/49:  2169 chars
#   page 22/49:  1533 chars
#   page 23/49:  1979 chars
#   page 24/49:  1968 chars
# ...

# %%
# @title A. Did OCR get the conjuncts right?
full = "\n".join(t for _, t in pages)
for token in ["শম্ভুনাথ", "কল্যাণী", "অনুপম", "সুপুরুষ", "মামা", "সৎপাত্র"]:
    print(f"{token:<12} {full.count(token):>4} occurrences")

# common Tesseract-style corruptions — all of these should be 0
for bad in ["শস্তুনাথ", "শন্তুনাথ", "িম্ভুনাথ"]:
    n = full.count(bad)
    print(f"{bad:<12} {n:>4}  {'<-- OCR still wrong' if n else 'ok'}")
# Out:
# শম্ভুনাথ       84 occurrences
# কল্যাণী        87 occurrences
# অনুপম         171 occurrences
# সুপুরুষ         4 occurrences
# মামা          142 occurrences
# সৎপাত্র         3 occurrences
# শস্তুনাথ        0  ok
# শন্তুনাথ        0  ok
# িম্ভুনাথ        0  ok

# %%
# @title B. Are the section page ranges right?
for p in [3, 8, 16, 20, 34, 43]:
    txt = clean_page(dict(pages).get(p, ""))
    print(f"--- page {p} [{section_of(p)}] ---")
    print(txt[:220].replace("\n", " "), "\n")
# Out:
# --- page 3 [glossary] ---
# HSC 26 | ONLINE BATCH |   | শব্দার্থ ও টীকা মূল শব্দ | শব্দের অর্থ ও ব্যাখ্যা এ জীবনটা না দৈর্ঘ্যের হিসেবে বড়ো, না গুণের হিসেবে | গল্পের কথক চরিত্র অনুপমের আত্মসমাালোচনা। পরিমাণ ও গুণ উভয় দিক দিয়েই যে তার জীবনটি নিতান
#
# --- page 8 [prose] ---
# “মন্দ নয় হে! খাঁটি সোনা বটে!” বিনুদার ভাষাটা অত্যন্ত আঁট। যেখানে আমরা বলি ‘চমৎকার’ সেখানে তিনি বলেন ‘চলনসই’। অতএব বুঝিলাম, আমার ভাগ্যে প্রজাপতির সঙ্গে পঞ্চশরের কোনো বিরোধ নাই। বলা বাহুল্য, বিবাহ-উপলক্ষ্যে কন্যপক্ষকেই কল
#
# --- page 16 [prose] ---
# আমি তো তাড়াতাড়ি ব্যস্ত হইয়া দাঁড়াইয়া উঠিলাম। মেয়েটি হিন্দিতে বলিল, “না, আমরা গাড়ি ছাড়িব না।” সে লোকটি রোখ করিয়া বলিল, “না ছাড়িয়া উপায় নাই।” কিন্তু, মেয়েটির চলিষ্ণুতার কোনো লক্ষণ না দেখিয়া সে নামিয়া গিয়া ই
#
# --- page 20 [mcq] ---
#
#
# --- page 34 [mcq] ---
# ...

# %%
# @title Evaluate

# Gold as regex, so an OCR variant doesn't silently read as a wrong answer.
GOLD = [
    ("অনুপমের ভাষায় সুপুরুষ কাকে বলা হয়েছে?",            r"শ[মস][্]?[ভত]?[ু]?নাথ"),
    ("কাকে অনুপমের ভাগ্য দেবতা বলে উল্লেখ করা হয়েছে?",     r"মামা"),
    ("বিয়ের সময় কল্যাণীর প্রকৃত বয়স কত ছিল?",             r"১৫|পনের|পনেরো|fifteen"),
    ("কল্যাণীর পিতার নাম কী?",                             r"শ[মস][্]?[ভত]?[ু]?নাথ"),
    ("Who is called a good match (সৎপাত্র) in the story?",  r"অনুপম|Anupam"),
]

ANSWER_BEARING = ("prose", "solution", "glossary")


def norm(s: str) -> str:
    return unicodedata.normalize("NFC", s or "")


def evaluate(rag: RAG, gold=GOLD, verbose=True):
    hits = oks = 0
    for q, pattern in gold:
        retrieved = rag.store.retrieve(q)
        hit = any(re.search(pattern, norm(c["text"])) and c["section"] in ANSWER_BEARING
                  for c in retrieved)
        ans = rag.ask(q)
        ok = bool(re.search(pattern, norm(ans)))
        hits += hit
        oks += ok
        print(f"{'HIT ' if hit else 'MISS'} | {'OK  ' if ok else 'BAD '} | {q}")
        print(f"        got={ans[:90]!r}")
        if verbose and not hit:
            print(f"        retrieved: {[(c['page'], c['section']) for c in retrieved]}")
    print(f"\nprose hit-rate {hits}/{len(gold)}   answer accuracy {oks}/{len(gold)}")


evaluate(rag)
# Out:
# MISS | BAD  | অনুপমের ভাষায় সুপুরুষ কাকে বলা হয়েছে?
#         got='প্রদত্ত তথ্যে উত্তর পাওয়া যায়নি।'
#         retrieved: [(42, 'solution'), (42, 'solution'), (46, 'solution'), (16, 'prose'), (35, 'mcq'), (34, 'mcq'), (36, 'mcq'), (37, 'mcq')]
# HIT  | OK   | কাকে অনুপমের ভাগ্য দেবতা বলে উল্লেখ করা হয়েছে?
#         got='মামাকে'
# MISS | OK   | বিয়ের সময় কল্যাণীর প্রকৃত বয়স কত ছিল?
#         got='১৫ বছর'
#         retrieved: [(45, 'solution'), (44, 'solution'), (42, 'solution'), (43, 'solution'), (35, 'mcq'), (35, 'mcq'), (35, 'mcq'), (34, 'mcq')]
# HIT  | OK   | কল্যাণীর পিতার নাম কী?
#         got='শম্ভুনাথ সেন'
# HIT  | OK   | Who is called a good match (সৎপাত্র) in the story?
#         got='প্রসঙ্গ অনুযায়ী, কন্যার পিতা মাত্রেই স্বীকার করিবেন যে অনুপম সৎপাত্র। অর্থাৎ **অনুপম**-কে '
#
# prose hit-rate 3/5   answer accuracy 4/5

# %%
# @title Interactive (type 'exit' to stop)
while True:
    q = input("\nQuestion: ").strip()
    if q.lower() in {"exit", "quit", ""}:
        print("Done.")
        break
    print("\n" + rag.ask(q, debug=True))
# Out:
# Question: বিয়ের সময় কল্যাণীর প্রকৃত বয়স কত ছিল?
#
# [retrieve] 'বিয়ের সময় কল্যাণীর প্রকৃত বয়স কত ছিল?'
#   p045_c002 p45 [solution] 0.0301 | খ. বিয়েবাড়িতে বরযাত্রীদের জায়গা সংকুলান না হওয়া এবং বিয়ের সমস্ত আয়োজন ও আতিথেয়তা
# প্রত্যাশিত ন...
#   p044_c001 p44 [solution] 0.0159 | তা খাঁটি কি না পরীক্ষা করেছে। তাই কল্যাণীর বিয়ে হয়নি। এই দিক বিচারে বলা যায়, প্রশ্নোক্ত মন্তব্যটি...
#   p042_c003 p42 [solution] 0.0156 | গ. যৌতুকের প্রতি মনোভাবের দিক থেকে উদ্দীপকের বরের বাপের সাথে ‘অপরিচিতা’ গল্পের অনুপমের
# মামার সাদৃশ্য...
#   p043_c002 p43 [solution] 0.0152 | সমাধান:
# ক. অনুপমের বন্ধু হরিশ কানপুরে কাজ করে।
#
# খ. শম্ভুনাথ সেন আলোচ্য উক্তির মধ্য দিয়ে একজোড়া ইয়...
#   p035_c002 p35 [mcq     ] 0.0323 | (ক) মায়ের প্রতি
# (খ) মাতৃভূমির প্রতি
# (গ) ধরণীর প্রতি
# (ঘ) অন্নপূর্ণার প্রতি
# ৪৬। বিয়ের সময় অনুপমের ব...
#   p035_c001 p35 [mcq     ] 0.0323 | ৩৯। 'এখানে জায়গা আছে' উক্তিটি কার?
# (ক) অর্দালির
# (খ) গার্ডের
# (গ) কল্যাণীর
# (ঘ) অনুপমের
# ৪০। স্টেশনে অন...
# ...

# %%
# @title Single question
print(rag.ask("কল্যাণীর পিতার নাম কী?", debug=True))
# Out:
# [retrieve] 'কল্যাণীর পিতার নাম কী?'
#   p042_c001 p42 [solution] 0.0309 | ক. অনুপমের পিসতুতো ভাইয়ের নাম কী?
# খ. “অন্নপূর্ণার কোলে গজাননের ছোট ভাইটি” - উক্তিটি ব্যাখ্যা কর।
# গ....
#   p016_c003 p16 [prose   ] 0.0287 | মেয়েটি বলিল, “আমার নাম কল্যাণী।”
# শুনিয়া মা এবং আমি দুজনেই চমকিয়া উঠিলাম।
# “তোমার বাবা-”
# “তিনি এখান...
#   p018_c001 p18 [prose   ] 0.0286 | নাম | প্রকৃত নাম: রবীন্দ্রনাথ ঠাকুর।
# ছদ্মনাম: ভানুসিংহ ঠাকুর।
# জন্ম পরিচয় | জন্ম তারিখ: ৭ মে, ১৮৬১ খ...
#   p046_c003 p46 [solution] 0.0253 | ক্ষমাপ্রার্থনা করে কল্যাণী ও তার পিতার কাছে। উদ্দীপকে মাতৃস্নেহের যে সীমাবদ্ধতার কথা বলা হয়েছে,
# অনু...
#   p034_c000 p34 [mcq     ] 0.0320 | HSC 26
# অনলাইন ব্যাচ
# MINUTE
# SCHOOL
# ২৪। 'অপরিচিতা' গল্পে কোন দ্বীপের উল্লেখ আছে?
# (ক) আন্দামান দ্বীপ
# (খ...
#   p035_c002 p35 [mcq     ] 0.0308 | (ক) মায়ের প্রতি
# (খ) মাতৃভূমির প্রতি
# (গ) ধরণীর প্রতি
# (ঘ) অন্নপূর্ণার প্রতি
# ৪৬। বিয়ের সময় অনুপমের ব...
# ...

# %%
q = "অনুপমের ভাষায় সুপুরুষ কাকে বলা হয়েছে?"

print("--- chunks containing সুপুরুষ ---")
for c in store.corpus:
    if "সুপুরুষ" in c["text"]:
        print(f"{c['id']} [{c['section']}] {c['text'][:120]}")

print("\n--- BM25 rank of each ---")
scores = store.bm25.get_scores(tokenize(q))
order = np.argsort(scores)[::-1]
for rank, idx in enumerate(order[:40]):
    c = store.corpus[idx]
    if "সুপুরুষ" in c["text"]:
        print(f"rank {rank:>3}  score {scores[idx]:.2f}  {c['id']} [{c['section']}]")
# Out:
# --- chunks containing সুপুরুষ ---
# p008_c000 [prose] “মন্দ নয় হে! খাঁটি সোনা বটে!” বিনুদার ভাষাটা অত্যন্ত আঁট। যেখানে আমরা বলি ‘চমৎকার’ সেখানে তিনি
# বলেন ‘চলনসই’। অতএব বুঝিল
# p026_c000 [mcq] HSC 26
# অনলাইন ব্যাচ
# বাংলা ইংরেজি আইসিটি
# MINUTE
# SCHOOL
#
# ৩০। 'আমার মতো অক্ষম দুনিয়ায় নাই।' - অনুপমের এই উক্তির মধ্য দিয়
# p037_c001 [mcq] ৬৯। কার সঙ্গে পঞ্চশরের বিরোধ নেই বলে অনুপমের মনে হলো?
# (ক) গজাননের
# (খ) কার্তিকের
# (গ) প্রজাপতির
# (ঘ) অন্নপূর্ণার
# ৭০। সুপুরু
#
# --- BM25 rank of each ---
# rank   1  score 6.06  p026_c000 [mcq]
# rank   5  score 5.28  p008_c000 [prose]
# rank  11  score 4.34  p037_c001 [mcq]
